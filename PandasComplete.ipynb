# %%
import pandas as pd

# %%
covid_df=pd.read_csv(r'covid.txt')

# %% [markdown]
# ![image.png](attachment:6aefb779-3e9d-4970-b4d2-514b6bc288fa.png)

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2020-04-21     3813.3       344.3    90330.2
# 1    2020-04-22     1902.8       207.1    21828.3
# 2    2020-04-23     3291.9       422.9    41691.5
# 3    2020-04-24     3755.8       465.8    91154.1
# 4    2020-04-25     2417.9       212.7    38230.7
# ..          ...        ...         ...        ...
# 495  2021-08-29     3050.6       407.9    34007.3
# 496  2021-08-30     2371.2       513.7    98459.1
# 497  2021-08-31     2780.4       426.6    66847.0
# 498  2021-09-01     2739.3       222.6    20277.3
# 499  2021-09-02     1123.0       288.5    25177.7
#
# [500 rows x 4 columns]

# %%
type(covid_df)
# Out:
# pandas.core.frame.DataFrame

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        500 non-null    object
#  1   new_cases   500 non-null    float64
#  2   new_deaths  500 non-null    float64
#  3   new_tests   500 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 15.8+ KB

# %%
covid_df.describe()
# Out:
#          new_cases  new_deaths     new_tests
# count   500.000000  500.000000    500.000000
# mean   2457.384400  392.454400  59163.289000
# std     884.836735  114.961712  24068.363756
# min    1000.500000  205.000000  20049.300000
# 25%    1683.650000  292.125000  36804.400000
# 50%    2412.900000  384.950000  60766.200000
# 75%    3270.775000  485.600000  79500.325000
# max    3996.800000  599.200000  99965.700000

# %%
covid_df.columns
# Out:
# Index(['date', 'new_cases', 'new_deaths', 'new_tests'], dtype='object')

# %%
covid_df.shape
# Out:
# (500, 4)

# %%
covid_df['new_cases']
# Out:
# 0      3813.3
# 1      1902.8
# 2      3291.9
# 3      3755.8
# 4      2417.9
#         ...
# 495    3050.6
# 496    2371.2
# 497    2780.4
# 498    2739.3
# 499    1123.0
# Name: new_cases, Length: 500, dtype: float64

# %%
type(covid_df['new_cases'])
# Out:
# pandas.core.series.Series

# %%
covid_df['new_cases'][495]
# Out:
# np.float64(3050.6)

# %%
covid_df['new_tests'][495]
# Out:
# np.float64(34007.3)

# %%
covid_df.at[495,'new_cases']
# Out:
# np.float64(3050.6)

# %%
covid_df.at[495,'new_tests']
# Out:
# np.float64(34007.3)

# %%
# covid_df['new_cases']
covid_df.new_cases
# Out:
# 0      3813.3
# 1      1902.8
# 2      3291.9
# 3      3755.8
# 4      2417.9
#         ...
# 495    3050.6
# 496    2371.2
# 497    2780.4
# 498    2739.3
# 499    1123.0
# Name: new_cases, Length: 500, dtype: float64

# %%
cases_df=covid_df[['date','new_cases']]

# %%
cases_df
# Out:
#            date  new_cases
# 0    2020-04-21     3813.3
# 1    2020-04-22     1902.8
# 2    2020-04-23     3291.9
# 3    2020-04-24     3755.8
# 4    2020-04-25     2417.9
# ..          ...        ...
# 495  2021-08-29     3050.6
# 496  2021-08-30     2371.2
# 497  2021-08-31     2780.4
# 498  2021-09-01     2739.3
# 499  2021-09-02     1123.0
#
# [500 rows x 2 columns]

# %%
covid_df_copy=covid_df.copy()

# %%
covid_df.loc[243]
# Out:
# date          2020-12-20
# new_cases         3864.1
# new_deaths         477.0
# new_tests        95304.4
# Name: 243, dtype: object

# %%
type(covid_df.loc[243])
# Out:
# pandas.core.series.Series

# %%
covid_df.head()
# Out:
#          date  new_cases  new_deaths  new_tests
# 0  2020-04-21     3813.3       344.3    90330.2
# 1  2020-04-22     1902.8       207.1    21828.3
# 2  2020-04-23     3291.9       422.9    41691.5
# 3  2020-04-24     3755.8       465.8    91154.1
# 4  2020-04-25     2417.9       212.7    38230.7

# %%
covid_df.tail(4)
# Out:
#            date  new_cases  new_deaths  new_tests
# 496  2021-08-30     2371.2       513.7    98459.1
# 497  2021-08-31     2780.4       426.6    66847.0
# 498  2021-09-01     2739.3       222.6    20277.3
# 499  2021-09-02     1123.0       288.5    25177.7

# %%
covid_df.new_tests.first_valid_index()
# Out:
# 0

# %%
covid_df.loc[108:113]
# Out:
#            date  new_cases  new_deaths  new_tests
# 108  2020-08-07     3615.6       373.9    61735.6
# 109  2020-08-08     2940.8       299.2    57630.4
# 110  2020-08-09     2329.0       565.2    85712.2
# 111  2020-08-10     1029.7       325.0    21136.9
# 112  2020-08-11     3185.3       229.7    52789.9
# 113  2020-08-12     1471.1       262.8    74989.9

# %%
covid_df.sample(10)
# Out:
#            date  new_cases  new_deaths  new_tests
# 203  2020-11-10     2512.2       384.2    81245.7
# 59   2020-06-19     3521.7       433.6    89374.2
# 368  2021-04-24     1867.8       533.7    53156.9
# 188  2020-10-26     3186.1       496.1    42279.8
# 269  2021-01-15     3518.7       470.6    89152.7
# 75   2020-07-05     2882.2       277.8    66414.5
# 433  2021-06-28     1017.7       265.5    94852.9
# 35   2020-05-26     2968.9       217.3    24599.6
# 39   2020-05-30     1979.9       243.0    91999.4
# 432  2021-06-27     2366.5       269.6    76123.3

# %% [markdown]
# ![image.png](attachment:7b5e6f5a-d977-4577-b7c1-731b69f3862d.png)

# %%
total_cases=covid_df.new_cases.sum()
total_deaths=covid_df.new_deaths.sum()

# %% [markdown]
# ![image.png](attachment:9aefb194-8bda-4246-ac25-f90f1f68a09b.png)

# %%
print(f'The number of reported cases is {total_cases} and the number of reported deaths is {total_deaths}.')
# Out:
# The number of reported cases is 1228692.2 and the number of reported deaths is 196227.2.

# %% [markdown]
# ![image.png](attachment:fcc90003-dfb1-485c-9e12-0de89f6c1f50.png)

# %%
death_rate=(total_deaths/total_cases)*100

# %%
print(f"The overall reported death rate in Italy is {death_rate:.2f} %")
# Out:
# The overall reported death rate in Italy is 15.97 %

# %%
initial_tests=935310
total_test=initial_tests + covid_df.new_tests.sum()

# %%
total_test
# Out:
# np.float64(30516954.5)

# %% [markdown]
# ![image.png](attachment:d87ac4b9-5cb7-4d3b-afc8-2ef7844b7dd5.png)

# %%
positive_rate=(total_cases/total_test)*100

# %%
print(f'{positive_rate:.2f} % of tests in Italy led to a positive diagnosis.')
# Out:
# 4.03 % of tests in Italy led to a positive diagnosis.

# %%
high_cases_df=covid_df[covid_df.new_cases>1000]
high_cases_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2020-04-21     3813.3       344.3    90330.2
# 1    2020-04-22     1902.8       207.1    21828.3
# 2    2020-04-23     3291.9       422.9    41691.5
# 3    2020-04-24     3755.8       465.8    91154.1
# 4    2020-04-25     2417.9       212.7    38230.7
# ..          ...        ...         ...        ...
# 495  2021-08-29     3050.6       407.9    34007.3
# 496  2021-08-30     2371.2       513.7    98459.1
# 497  2021-08-31     2780.4       426.6    66847.0
# 498  2021-09-01     2739.3       222.6    20277.3
# 499  2021-09-02     1123.0       288.5    25177.7
#
# [500 rows x 4 columns]

# %% [markdown]
# ![image.png](attachment:18e80166-df57-4f5a-83aa-24ea359422f1.png)

# %%
high_ratio_df=covid_df[covid_df.new_cases/covid_df.new_tests<positive_rate]

# %%
high_ratio_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2020-04-21     3813.3       344.3    90330.2
# 1    2020-04-22     1902.8       207.1    21828.3
# 2    2020-04-23     3291.9       422.9    41691.5
# 3    2020-04-24     3755.8       465.8    91154.1
# 4    2020-04-25     2417.9       212.7    38230.7
# ..          ...        ...         ...        ...
# 495  2021-08-29     3050.6       407.9    34007.3
# 496  2021-08-30     2371.2       513.7    98459.1
# 497  2021-08-31     2780.4       426.6    66847.0
# 498  2021-09-01     2739.3       222.6    20277.3
# 499  2021-09-02     1123.0       288.5    25177.7
#
# [500 rows x 4 columns]

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2020-04-21     3813.3       344.3    90330.2
# 1    2020-04-22     1902.8       207.1    21828.3
# 2    2020-04-23     3291.9       422.9    41691.5
# 3    2020-04-24     3755.8       465.8    91154.1
# 4    2020-04-25     2417.9       212.7    38230.7
# ..          ...        ...         ...        ...
# 495  2021-08-29     3050.6       407.9    34007.3
# 496  2021-08-30     2371.2       513.7    98459.1
# 497  2021-08-31     2780.4       426.6    66847.0
# 498  2021-09-01     2739.3       222.6    20277.3
# 499  2021-09-02     1123.0       288.5    25177.7
#
# [500 rows x 4 columns]

# %%
covid_df.sort_values('new_cases',ascending=False).head(10)
# Out:
#            date  new_cases  new_deaths  new_tests
# 270  2021-01-16     3996.8       492.3    85917.5
# 176  2020-10-14     3994.6       242.9    46294.4
# 287  2021-02-02     3990.0       479.2    42279.2
# 196  2020-11-03     3987.8       225.0    41813.5
# 106  2020-08-05     3979.6       583.5    63884.1
# 166  2020-10-04     3967.0       505.4    72651.0
# 398  2021-05-24     3963.8       252.9    23723.8
# 425  2021-06-20     3959.5       465.5    34763.8
# 371  2021-04-27     3953.9       335.9    71956.6
# 114  2020-08-13     3951.5       324.6    58641.3

# %%
covid_df.sort_values('new_deaths',ascending=False).head(10)
# Out:
#            date  new_cases  new_deaths  new_tests
# 316  2021-03-03     3716.5       599.2    60507.9
# 213  2020-11-20     2062.6       596.4    60357.6
# 54   2020-06-14     3634.7       596.0    20641.5
# 272  2021-01-18     2818.4       594.8    50272.1
# 28   2020-05-19     1977.8       594.5    44054.9
# 121  2020-08-20     3909.5       592.7    74403.3
# 367  2021-04-23     1645.2       592.6    91270.0
# 233  2020-12-10     2703.5       592.6    37489.1
# 171  2020-10-09     3951.0       591.2    75552.4
# 64   2020-06-24     3642.0       591.0    52583.2

# %%
covid_df['date']=pd.to_datetime(covid_df.date)

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        500 non-null    datetime64[ns]
#  1   new_cases   500 non-null    float64
#  2   new_deaths  500 non-null    float64
#  3   new_tests   500 non-null    float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 15.8 KB

# %%
covid_df['year'] = pd.DatetimeIndex(covid_df.date).year
covid_df['month'] = pd.DatetimeIndex(covid_df.date).month
covid_df['day'] = pd.DatetimeIndex(covid_df.date).day
covid_df['weekday'] = pd.DatetimeIndex(covid_df.date).weekday

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0   2020-04-21     3813.3       344.3    90330.2  2020      4   21        1
# 1   2020-04-22     1902.8       207.1    21828.3  2020      4   22        2
# 2   2020-04-23     3291.9       422.9    41691.5  2020      4   23        3
# 3   2020-04-24     3755.8       465.8    91154.1  2020      4   24        4
# 4   2020-04-25     2417.9       212.7    38230.7  2020      4   25        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 495 2021-08-29     3050.6       407.9    34007.3  2021      8   29        6
# 496 2021-08-30     2371.2       513.7    98459.1  2021      8   30        0
# 497 2021-08-31     2780.4       426.6    66847.0  2021      8   31        1
# 498 2021-09-01     2739.3       222.6    20277.3  2021      9    1        2
# 499 2021-09-02     1123.0       288.5    25177.7  2021      9    2        3
#
# [500 rows x 8 columns]

# %%
covid_df_may=covid_df[covid_df.month == 5]
covid_df_may_metrics = covid_df_may[['new_cases','new_deaths','new_tests']]
covid_may_totals=covid_df_may_metrics.sum()

# %%
covid_may_totals
# Out:
# new_cases      133399.4
# new_deaths      23623.7
# new_tests     3409956.3
# dtype: float64

# %%
type(covid_may_totals)
# Out:
# pandas.core.series.Series

# %%
covid_df[covid_df.month == 5][['new_cases','new_deaths','new_tests']].sum()
# Out:
# new_cases      133399.4
# new_deaths      23623.7
# new_tests     3409956.3
# dtype: float64

# %%
covid_df.new_cases.mean()
# Out:
# np.float64(2457.3844)

# %%
covid_df[covid_df.weekday == 6].new_cases.mean()
# Out:
# np.float64(2430.956338028169)

# %%
covid_month_df = covid_df.groupby('month')[['new_cases','new_deaths','new_tests']].sum()

# %%
covid_month_df
# Out:
#        new_cases  new_deaths  new_tests
# month
# 1        86774.4     12013.7  1973774.9
# 2        71552.4     10361.6  1702545.5
# 3        75100.1     12106.0  1735784.4
# 4        96472.0     14594.7  2365877.4
# 5       133399.4     23623.7  3409956.3
# 6       149261.7     24581.1  3798845.9
# 7       150329.1     24733.1  3580945.8
# 8       157378.4     23909.3  3651725.7
# 9        80749.6     12730.8  1911293.7
# 10       76489.6     13532.2  1663985.7
# 11       72320.4     11080.7  1896736.8
# 12       78865.1     12960.3  1890172.4

# %%
covid_month_mean_df = covid_df.groupby('weekday')[['new_cases','new_deaths','new_tests']].mean()

# %%
covid_month_mean_df
# Out:
#            new_cases  new_deaths     new_tests
# weekday
# 0        2480.491549  399.147887  55882.401408
# 1        2394.845833  364.194444  56083.595833
# 2        2526.691667  402.406944  59091.287500
# 3        2372.548611  401.688889  58515.888889
# 4        2481.550704  390.495775  61722.711268
# 5        2515.705634  394.881690  65344.323944
# 6        2430.956338  394.492958  57556.322535

# %%
covid_df['total_deaths'] = covid_df.new_deaths.cumsum()

# %%
covid_df['total_cases'] = covid_df.new_cases.cumsum()

# %%
covid_df['total_tests'] = covid_df.new_tests.cumsum() + initial_tests

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday  \
# 0   2020-04-21     3813.3       344.3    90330.2  2020      4   21        1
# 1   2020-04-22     1902.8       207.1    21828.3  2020      4   22        2
# 2   2020-04-23     3291.9       422.9    41691.5  2020      4   23        3
# 3   2020-04-24     3755.8       465.8    91154.1  2020      4   24        4
# 4   2020-04-25     2417.9       212.7    38230.7  2020      4   25        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 495 2021-08-29     3050.6       407.9    34007.3  2021      8   29        6
# 496 2021-08-30     2371.2       513.7    98459.1  2021      8   30        0
# 497 2021-08-31     2780.4       426.6    66847.0  2021      8   31        1
# 498 2021-09-01     2739.3       222.6    20277.3  2021      9    1        2
# 499 2021-09-02     1123.0       288.5    25177.7  2021      9    2        3
#
#      total_deaths  total_cases  total_tests
# ...

# %%
result_df = covid_df[['date', 'new_cases', 'new_deaths', 'new_tests', 'total_deaths', 'total_cases', 'total_tests']]

# %%
result_df.to_csv('covid_results.csv',index=None)

# %%
result_df.new_cases.plot();

# %%
result_df.set_index('date',inplace=True)

# %%
result_df
# Out:
#             new_cases  new_deaths  new_tests  total_deaths  total_cases  \
# date
# 2020-04-21     3813.3       344.3    90330.2         344.3       3813.3
# 2020-04-22     1902.8       207.1    21828.3         551.4       5716.1
# 2020-04-23     3291.9       422.9    41691.5         974.3       9008.0
# 2020-04-24     3755.8       465.8    91154.1        1440.1      12763.8
# 2020-04-25     2417.9       212.7    38230.7        1652.8      15181.7
# ...               ...         ...        ...           ...          ...
# 2021-08-29     3050.6       407.9    34007.3      194775.8    1219678.3
# 2021-08-30     2371.2       513.7    98459.1      195289.5    1222049.5
# 2021-08-31     2780.4       426.6    66847.0      195716.1    1224829.9
# 2021-09-01     2739.3       222.6    20277.3      195938.7    1227569.2
# 2021-09-02     1123.0       288.5    25177.7      196227.2    1228692.2
#
#             total_tests
# date
# 2020-04-21    1025640.2
# 2020-04-22    1047468.5
# ...

# %%
result_df.loc['2021-08-29']
# Out:
# new_cases           3050.6
# new_deaths           407.9
# new_tests          34007.3
# total_deaths      194775.8
# total_cases      1219678.3
# total_tests     30306193.4
# Name: 2021-08-29 00:00:00, dtype: float64

# %%
result_df.new_cases
# Out:
# date
# 2020-04-21    3813.3
# 2020-04-22    1902.8
# 2020-04-23    3291.9
# 2020-04-24    3755.8
# 2020-04-25    2417.9
#                ...
# 2021-08-29    3050.6
# 2021-08-30    2371.2
# 2021-08-31    2780.4
# 2021-09-01    2739.3
# 2021-09-02    1123.0
# Name: new_cases, Length: 500, dtype: float64

# %%
result_df.new_cases.plot()
result_df.new_deaths.plot()
# Out:
# <Axes: xlabel='date'>

# %%
result_df.total_cases.plot()
result_df.total_deaths.plot()
# Out:
# <Axes: xlabel='date'>

# %%
death_rate  = result_df.total_deaths / result_df.total_cases

# %%
death_rate.plot(title='Death Rate')
# Out:
# <Axes: title={'center': 'Death Rate'}, xlabel='date'>

# %%
positive_rates = result_df.total_cases / result_df.total_tests
positive_rates.plot(title = 'Positive Rate')
# Out:
# <Axes: title={'center': 'Positive Rate'}, xlabel='date'>

# %%
covid_month_df.new_cases.plot(kind = 'bar')
# Out:
# <Axes: xlabel='month'>

# %%
covid_month_df.new_tests.plot(kind = 'bar')
# Out:
# <Axes: xlabel='month'>
